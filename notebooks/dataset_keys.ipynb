# %% [markdown]
# # Keys for the 14 Datasets

# %%
import datajoint as dj
dj.config["database.host"] = '18.198.155.36'

dj.config["display.limit"] = 15

from dataport.bcm.static import PreprocessedMouseData

# %%
keys = [{'animal_id': 21067,
  'session': 9,
  'scan_idx': 17,
  'filename': 'static21067-9-17-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 21067,
  'session': 10,
  'scan_idx': 18,
  'filename': 'static21067-10-18-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 21067,
  'session': 13,
  'scan_idx': 14,
  'filename': 'static21067-13-14-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 22620,
  'session': 4,
  'scan_idx': 15,
  'filename': 'static22620-4-15-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 22620,
  'session': 4,
  'scan_idx': 17,
  'filename': 'static22620-4-17-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 22620,
  'session': 5,
  'scan_idx': 11,
  'filename': 'static22620-5-11-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 22846,
  'session': 2,
  'scan_idx': 19,
  'filename': 'static22846-2-19-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 22846,
  'session': 2,
  'scan_idx': 21,
  'filename': 'static22846-2-21-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 22846,
  'session': 7,
  'scan_idx': 15,
  'filename': 'static22846-7-15-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 22846,
  'session': 10,
  'scan_idx': 16,
  'filename': 'static22846-10-16-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 23343,
  'session': 5,
  'scan_idx': 17,
  'filename': 'static23343-5-17-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 23555,
  'session': 5,
  'scan_idx': 12,
  'filename': 'static23555-5-12-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 23656,
  'session': 14,
  'scan_idx': 22,
  'filename': 'static23656-14-22-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'},
 {'animal_id': 23964,
  'session': 4,
  'scan_idx': 22,
  'filename': 'static23964-4-22-GrayImageNet-e174a2ed1deec79edcf87e2a33fbe9c5.zip'}]

# %% [markdown]
# # Datasets in the respective Table

# %%
PreprocessedMouseData & keys
# Out:
# *animal_id    *session    *scan_idx    *filename      data       comment
# +-----------+ +---------+ +----------+ +------------+ +--------+ +------------+
# 21067         9           17           static21067-9- =BLOB=     21067-9-17, Ne
# 21067         10          18           static21067-10 =BLOB=     21067-10-18, N
# 21067         13          14           static21067-13 =BLOB=     21067-13-14, N
# 22620         4           15           static22620-4- =BLOB=     22620-4-15, Ne
# 22620         4           17           static22620-4- =BLOB=     22620-4-17, Ne
# 22620         5           11           static22620-5- =BLOB=     22620-5-11, Ne
# 22846         2           19           static22846-2- =BLOB=     22846-2-19, Ne
# 22846         2           21           static22846-2- =BLOB=     22846-2-21, Ne
# 22846         7           15           static22846-7- =BLOB=     22846-7-15, Ne
# 22846         10          16           static22846-10 =BLOB=     22846-10-16, N
# ...
